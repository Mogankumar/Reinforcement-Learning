# %%
import gymnasium as gym
from gymnasium import spaces
import matplotlib.pyplot as plt
import numpy as np

# %%
grid = np.zeros((3,3))
print(grid)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
pos1 = [0,0]
pos2 = [2,2]

grid[tuple(pos1)] = 1
grid[tuple(pos2)] = 0.8

plt.imshow(grid)
